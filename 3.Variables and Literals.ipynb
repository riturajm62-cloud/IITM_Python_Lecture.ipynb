# %%
print('Type your name:')
n=str(input())
print('Type your location:')
p=str(input())
print('Hello',n,'how is the weather in',p,'?')
print('What is your age?')
age=int(input())
print('Good to know that you are',age, 'years old')
# Out:
# Type your name:
#  Ritu Raj
# Type your location:
#  Patna
# Hello Ritu Raj how is the weather in Patna ?
# What is your age?
#  23
# Good to know that you are 23 years old

# %%
n=str(input("Type your name:"))
p=str(input("Type your location:"))
print("Hello",n,"how is the weather in",p,"?")
age=int(input("What is your age?"))
print("Good to know that you are ",age,"years old")
# Out:
# Type your name: Ritu Raj
# Type your location: Patna
# Hello Ritu Raj how is the weather in Patna ?
# What is your age? 23
# Good to know that you are  23 years old

# %%
r = int(input("Enter the radius of circle:"))
area=3.14*r*r
print("Area of the circle with radius",r,"is","area")
# Out:
# Enter the radius of circle: 5
# Area of the circle with radius 5 is area
