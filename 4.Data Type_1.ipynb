# %%
n=10
print(n)
r=6.3
print(r)
s='Ritu Raj'
print(s)

print("n is of type:", type(n))
print("r is of type:", type(r))
print("s is of type:", type(s))
# Out:
# 10
# 6.3
# Ritu Raj
# n is of type: <class 'int'>
# r is of type: <class 'float'>
# s is of type: <class 'str'>

# %%
l=[10,20,30] # This is a list.
print(l)
print(l[0])
print(l[1])
print(l[2])
print(type(l))
print(type(l[2]))
# Out:
# [10, 20, 30]
# 10
# 20
# 30
# <class 'list'>
# <class 'int'>
