# %%
n=3*2
print(n)
# Out:
# 6

# %%
a=1
b=2
print(a+b)
# Out:
# 3

# %%
a='Ritu Raj' 
b='India'
n=a+b #Concatenation
print(n)
# Out:
# Ritu RajIndia

# %%
a=[1,2,3]
b=[7,9,3]
n=a+b #
print(n)
# Out:
# [1, 2, 3, 7, 9, 3]

# %%
a=11
b=15
n=a/b
print(n)
# Out:
# 0.7333333333333333

# %%
n=13+10*2 # operator precedence.
print(n)
# Out:
# 33
