# %%
s=('Coffee')
t=('Bread')
print(s)
print(t)
print(s +  t)
print(s[1:3]) # String Slicing
# Out:
# Coffee
# Bread
# CoffeeBread
# of

# %%
s='0123456789'
a=int(s[4])
b=int(s[5])
print(a)
print(b)
print(a+b)
# Out:
# 4
# 5
# 9

# %%
s='0123456789'
a=(s[4])
b=(s[5])
n=int(a+b)
print(n)
# Out:
# 45

# %%
s='0123456789'
a=int(s[4])
b=int(s[5])
n=(a+b)
print(n)
# Out:
# 9
