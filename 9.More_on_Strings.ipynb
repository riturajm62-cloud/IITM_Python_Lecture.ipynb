# %%
# Replication
s='Good'
print(5 * s)
print(s[0] *5 )
# Out:
# GoodGoodGoodGoodGood
# GGGGG

# %%
# String Comparision
x= 'India'
print(x == 'India')
print(x == 'india')
# Out:
# True
# False

# %%
print('apple' > 'one')
print('four' < 'ten')
# Out:
# False
# True

# %%
print('ab' < 'az') # comparre first "a" with "a" and then "b" with "z'
# Out:
# True

# %%
# String indexing
s='Python'
print(s[0])
print(s[1])
print(s[2])
print(s[3])
print(s[4])
print(s[5])
print(s[-1]) # Negative Indexing
print(s[-2])
print(s[-4])
print(len(s)) # len function give length of string that is number of character in string.
# Out:
# P
# y
# t
# h
# o
# n
# n
# o
# t
# 6
