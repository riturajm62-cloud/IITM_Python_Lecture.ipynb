# %%
l=12
r=5.8
s="Indian"
b1= True
b2= False
print(type(l))
print(type(r))
print(type(s))
print(type(b1))
print(type(b2))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'bool'>

# %%
a= float(9)
b= float('5.3')

print(a, type(a))
print(b, type(b))
# Out:
# 9.0 <class 'float'>
# 5.3 <class 'float'>

# %%
a=int(5.8)
b=int('10')

print(a, type(a))
print(b, type(b))
# Out:
# 5 <class 'int'>
# 10 <class 'int'>

# %%
a=bool(5.8)
b=bool('10')
c=bool(0)
e=bool('')

print(a, type(a))
print(b, type(b))
print(c, type(c))
print(e, type(e))
# Out:
# True <class 'bool'>
# True <class 'bool'>
# False <class 'bool'>
# False <class 'bool'>
