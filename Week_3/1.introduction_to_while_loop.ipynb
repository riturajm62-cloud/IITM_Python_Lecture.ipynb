# %%
print("When did India get its independence (Year)")
year=int(input())

if (year==1947):
    print("Hip Hip Hurray, You got that right!")
else:
    print("Comeon don't you know even this!")
    print("That's ok, I will let you attempt this once more")
    print("When did India get its independence (Year)")
    year=int(input())
    if (year==1947):
        print("You got it")
    else:
        print("Failed in your second attempt too")
# Out:
# When did India get its independence (Year)
#  147
# Comeon don't you know even this!
# That's ok, I will let you attempt this once more
# When did India get its independence (Year)
#  1947
# You got it

# %%
print("When did India get its independence (Year)")
year=int(input())

while(year!=1947):
    print("You got this wrong, Enter once again.")
    year=int(input())

print("Wowwww... you got it right!")
# Out:
# When did India get its independence (Year)
#  1214
# You got this wrong, Enter once again.
#  1947
# Wowwww... you got it right!
