# %%
s='VIBGYOR'

print(s[0])
print(s[1])
print(s[2])
print(s[3])
print(s[4])
print(s[5])
print(s[6])
# Out:
# V
# I
# B
# G
# Y
# O
# R

# %%
s='VIBGYOR'

for i in range(7):
    print(s[i])
# Out:
# V
# I
# B
# G
# Y
# O
# R

# %%
s='VIBGYOR'
t='VIBGYOR'

count=0
for i in range(7):
    for j in range(7):
        print(i,j,s[i],t[j])
        count=count+1

print("The total ways in which the two brothers can wear 7 different colours:",count)
# Out:
# 0 0 V V
# 0 1 V I
# 0 2 V B
# 0 3 V G
# 0 4 V Y
# 0 5 V O
# 0 6 V R
# 1 0 I V
# 1 1 I I
# 1 2 I B
# 1 3 I G
# 1 4 I Y
# 1 5 I O
# 1 6 I R
# 2 0 B V
# 2 1 B I
# 2 2 B B
# 2 3 B G
# 2 4 B Y
# 2 5 B O
# 2 6 B R
# 3 0 G V
# 3 1 G I
# 3 2 G B
# 3 3 G G
# 3 4 G Y
# 3 5 G O
# 3 6 G R
# 4 0 Y V
# 4 1 Y I
# 4 2 Y B
# 4 3 Y G
# 4 4 Y Y
# 4 5 Y O
# 4 6 Y R
# 5 0 O V
# 5 1 O I
# 5 2 O B
# 5 3 O G
# 5 4 O Y
# 5 5 O O
# 5 6 O R
# 6 0 R V
# 6 1 R I
# 6 2 R B
# 6 3 R G
# 6 4 R Y
# 6 5 R O
# 6 6 R R
# The total ways in which the two brothers can wear 7 different colours: 49
