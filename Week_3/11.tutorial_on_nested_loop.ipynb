# %%
# Find all prime numbers less than the entered number
num = int(input('Enter a number'))
if (num > 2):
    print(2, end= ' ')
for i in range(3, num):
    flag=False
    for j in range(2, i):
        if(i % j == 0):
            flag=False
            break
        else:
            flag=True
        if(flag):
            print(i, end = ' ')
# Out:
# Enter a number 9
# 2 3 5 5 5 7 7 7 7 7

# %%
'''Find the total profit/loss of each trader working in a trading firm .
Information regarding number of traders and number of transactions are unknown.'''

empID = input('Enter employee ID: ')
while (empID != '-1'):
    trade = int(input('Enter the trade amount: '))
    profit_loss = 0
    while(trade != 0):
        profit_loss = profit_loss + trade
        trade = int(input('Enter the trade amount: '))
    print(f'Profit/loss for employee {empID} is {profit_loss}')
    emp_ID = input('\n Enter employee ID:)')
# Out:
# Enter employee ID:  SJ_323
# Enter the trade amount:  3534
# Enter the trade amount:  56456
# Enter the trade amount:  -2432
# Enter the trade amount:  0
# Profit/loss for employee SJ_323 is 57558

# %%
# Find the day wise total rainfall for the entered duration of time e.g week, month etc
days = int(input('Enter the number of days: '))
for i in range(1, days + 1):
    total = 0
    rainfall = int(input('Enter the rainfall: '))
    while(rainfall != -1):
        total = total + rainfall
        rainfall = int(input('Enter the rainfall: '))
    print('Total rainfall for day {0} is {1}' .format(i,total))
# Out:
# Enter the number of days:  7
# Enter the rainfall:  10
# Enter the rainfall:  15
# Enter the rainfall:  19
# Enter the rainfall:  5
# Enter the rainfall:  -1
# Total rainfall for day 1 is 49

# %%
#find the length of longest word from the set of words entered by the user
word = input('Enter a word: ')
maxLen = 0
while (word != '-1'):
    count = 0
    for letter in word:
        count = count + 1 
    if (count > maxLen):
        maxLen = count
    word = input('Enter a word: ')
print('The length of longest word is %s'  %maxLen)
# Out:
# Enter a word:  of
# Enter a word:  science
# Enter a word:  -1
# The length of longest word is 7
