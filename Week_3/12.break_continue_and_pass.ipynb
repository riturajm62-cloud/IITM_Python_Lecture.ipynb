# %%
# xyz123@iitm.in
email = input()
for c in email:
    if(c== '@'):
        break
    print(c)
# Out:
#  xyz123@iitm.in
# x
# y
# z
# 1
# 2
# 3

# %%
# xyz123@iitm.in
email = input()
for c in email:
    if(c== '@'):
        continue
    print(c, end = '')
# Out:
#  xyz123@iitm.in
# xyz123iitm.in

# %%
for x in range(11):
    if(x%3==0):
        print(x)
    else:
        pass
# Out:
# 0
# 3
# 6
# 9
