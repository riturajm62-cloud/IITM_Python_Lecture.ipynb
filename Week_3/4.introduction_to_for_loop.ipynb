# %%
for i in range(5):
    print(i, "Hello Ritu Raj")
    print("***")
# Out:
# 0 Hello Ritu Raj
# ***
# 1 Hello Ritu Raj
# ***
# 2 Hello Ritu Raj
# ***
# 3 Hello Ritu Raj
# ***
# 4 Hello Ritu Raj
# ***

# %%
print('Enter a number')
n=int(input())

for i in range(n):
    if (i%2==0):
        print(i, "Hello Ritu Raj")
        print("***")
    else:
        print(i, "Hi")
# Out:
# Enter a number
#  5
# 0 Hello Ritu Raj
# ***
# 1 Hi
# 2 Hello Ritu Raj
# ***
# 3 Hi
# 4 Hello Ritu Raj
# ***
