# %%
l=[1,4,2,100]
print(l)
l.append(1024)
print(l)
l.append(2)
print(l)
l.remove(1)
print(l)
l.remove(2) #Remove the first occurance of 2
print(l)
# Out:
# [1, 4, 2, 100]
# [1, 4, 2, 100, 1024]
# [1, 4, 2, 100, 1024, 2]
# [4, 2, 100, 1024, 2]
# [4, 100, 1024, 2]

# %%
l=[]
l.append(1)
l.append(2)
l.append(3)
print(l)
x=[]
x.append(l)
print(x)
m=[10,20,30]
x.append(m)
print(x)
t=[]
t.append(x)
print(t)
t.append([100,101,102])
print(t)
print(t[0])
M=[]
M.append([1,2,3])
M.append([4,5,6])
M.append([7,8,9])
print(M)
M[0]
M[0][1]
# Out:
# [1, 2, 3]
# [[1, 2, 3]]
# [[1, 2, 3], [10, 20, 30]]
# [[[1, 2, 3], [10, 20, 30]]]
# [[[1, 2, 3], [10, 20, 30]], [100, 101, 102]]
# [[1, 2, 3], [10, 20, 30]]
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# 2
