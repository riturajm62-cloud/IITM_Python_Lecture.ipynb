# %%
'''
#Inbuilt function
print(),input(),len()
#library functions
log(),sqrt(),random(),randrnge(),calendar(),month()
#string method function
upper(),lower(),strip(),count(),index(),replace()
'''

#user defined function
def square(x):
    sqr =x**2
    return sqr

print(square(5))
# Out:
# 25
