# %%
# list is mutable , tuples are immutable
# most common applicaion of tuple is packing and unpacking.
t=1,2,3
print(t, type(t))

x, y, z = t
print(x, y, z)
# Out:
# (1, 2, 3) <class 'tuple'>
# 1 2 3

# %%
x=5
y=10
x,y=y,x
print(x,y)
# Out:
# 10 5

# %%
k=[10]
print(k, type(k))

t=(10,)
print(t, type(t))
# Out:
# [10] <class 'list'>
# (10,) <class 'tuple'>

# %%
t=([1,2],['a','b'])
print(t)
# Out:
# ([1, 2], ['a', 'b'])

# %%
t=([1,2],['a','b'])
t[0][0]=10
print(t)
# Out:
# ([10, 2], ['a', 'b'])

# %%
t1(1,2,3)
t2=([1,2,3],)
