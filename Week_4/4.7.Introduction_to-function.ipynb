# %%
def add(a,b):
    ans=a+b
    print(ans)

# %%
add(1,6)
# Out:
# 7

# %%
add(10,72)
# Out:
# 82

# %%
def sub(a,b):
    ans=a-b
    print(ans)

# %%
sub(10,2)
# Out:
# 8

# %%
add(10,7)
# Out:
# 17

# %%
def discount(cost,d):
    ans=cost-(cost*d/100)
    print(ans)

# %%
discount(1200,8)
# Out:
# 1104.0

# %%
discount(91234568524123,23)
# Out:
# 70250617763574.71

# %%
def add(a,b):
    ans=a+b
    return ans

a=2
b=15
print(add(a,b))
# Out:
# 17

# %%
ans=add(a,b)+10
print(ans)
# Out:
# 27

# %%
def discount(cost,d):
    ans=cost-(cost*d/100)
    return ans

print("Enter a cost price")
c=int(input())
print("Enter the discount")
disc=int(input())

print("the final discount is:", discount(c,disc))
# Out:
# Enter a cost price
#  1000
# Enter the discount
#  10
# the final discount is: 900.0

# %%
def discount(cost,d):
    ans=cost-(cost*d/100)
    return ans

print("Enter a cost price")
x=int(input())
print("Enter the discount")
y=int(input())

print("the final discount is:", discount(x,y))
# Out:
# Enter a cost price
#  1000
# Enter the discount
#  10
# the final discount is: 900.0
