# %%
#Escape character
print('it\'s a beautiful day')
print("We are from \"IIT\" Madras")
# Out:
# it's a beautiful day
# We are from "IIT" Madras

# %%
print("it's a beautiful day")
print('We are from "IIT" Madras')
# Out:
# it's a beautiful day
# We are from "IIT" Madras

# %%
print('My name is Ritu Raj,\t I am from patna')
# Out:
# My name is Ritu Raj,	 I am from patna

# %%
print('My name is Ritu Raj,\nI am from Patna')
# Out:
# My name is Ritu Raj,
# I am from Patna

# %%
# Use of quotes
x='This is a string'
y="This is also a sting"
z='''firstline
second line
thirdline'''
print(x)
print(y)
print(z)
# Out:
# This is a string
# This is also a sting
# firstline
# second line
# thirdline
