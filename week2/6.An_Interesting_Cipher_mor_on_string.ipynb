# %%
alpha='abcdefghijklmnopqrstuvwxyz'
print(alpha[0])
print(alpha[10])
# Out:
# a
# k

# %%
alpha='abcdefghijklmnopqrstuvwxyz'
i=5
print(alpha[i])
print(alpha[i+1])
print(alpha[i+3])
# Out:
# f
# g
# i

# %%
C
i=27
print(alpha[i%2])
print(alpha[(i+2)%5])
# Out:
# b
# e

# %%
alpha='abcdefghijklmnopqrstuvwxyz'

r='rituraj'
t=''
alpha.index(r[0])
# Out:
# 17
