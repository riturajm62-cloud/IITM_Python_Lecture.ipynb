# %%
print("Please enter yourdate of birth")
birth_year=int(input())
current_year=2026
age=current_year-birth_year
if (age<13):
    print("You are under age, you can't watch this movie")
else:
    print("You are old enough to watch this movie, enjoy")
# Out:
# Please enter yourdate of birth
#  2002
# You are old enough to watch this movie, enjoy
