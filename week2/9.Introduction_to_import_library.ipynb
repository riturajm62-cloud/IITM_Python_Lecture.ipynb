# %%
import math
print(math.log(10))
print(math.sin(45))
print(math.sqrt(16))
print(math.factorial(5))
# Out:
# 2.302585092994046
# 0.8509035245341184
# 4.0
# 120

# %%
import random
print(random.random()) # on executing each time you will get different number between 0 and1.
# Out:
# 0.9008274673500548

# %%
# let us simulate a coin toss
import random
a=random.random()

if(a<.5):
    print("Head")
else:
    print("Tail")
# Out:
# Head

# %%
# Simulate six faced dice
import random
dice1=(random.randrange(1,7))
dice2=(random.randrange(1,7))
total=dice1+dice2

print("Your pair of dice is: ",total)
# Out:
# Your pair of dice is:  5
